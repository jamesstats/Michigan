# %%
import tabula
from tabula import read_pdf 
import pandas as pd
import numpy as np

# %%
df=gov=tabula.read_pdf("ingham.pdf", pages='9-19')

# %%
print(df)
# Out:
# [                            Precinct Unnamed: 0 Unnamed: 1  \
# 0                             County        NaN        NaN
# 1             Ingham County Michigan        NaN        NaN
# 2      Alaiedon Township, Precinct 1        NaN        NaN
# 3                       Election Day        866      1,212
# 4                 AV Counting Boards          0      1,212
# ..                               ...        ...        ...
# 84                AV Counting Boards        632      1,659
# 85                             Total      1,101      1,659
# 86  City of East Lansing, Precinct 8        NaN        NaN
# 87                      Election Day        222      1,040
# 88                AV Counting Boards        343      1,040
#
#                           Precinct.1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                             County         NaN         NaN         NaN
# 1             Ingham County Michigan         NaN         NaN         NaN
# ...

# %%
df.to_csv("migov.csv", index=False)
